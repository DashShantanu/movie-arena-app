# %%
import numpy as np
import pandas as pd

# %%
# import get_data function from preprocess wiki file
from preprocess_wiki import get_data

# get data from 2019, 2020, 2021, 2022
get_data(2019)
get_data(2020)
get_data(2021)
get_data(2022)
# Out:
#              Opening  Opening.1              Title
# 0      J A N U A R Y          4        Escape Room  \
# 1      J A N U A R Y          4         Rust Creek
# 2      J A N U A R Y          4   American Hangman
# 3      J A N U A R Y         11   A Dog's Way Home
# 4      J A N U A R Y         11         The Upside
# ..               ...        ...                ...
# 240  D E C E M B E R         25  Spies in Disguise
# 241  D E C E M B E R         25       Little Women
# 242  D E C E M B E R         25               1917
# 243  D E C E M B E R         25         Just Mercy
# 244  D E C E M B E R         27           Clemency
#
#                                     Production company
# 0                    Columbia Pictures / Original Film  \
# 1                       IFC Films / Lunacy Productions
# 2                          Hangman Justice Productions
# 3                                    Columbia Pictures
# 4                                    STX Entertainment
# ...

# %%
df_19 = pd.read_csv('datasets/new_data2019.csv')
df_20 = pd.read_csv('datasets/new_data2020.csv')
df_21 = pd.read_csv('datasets/new_data2021.csv')
df_22 = pd.read_csv('datasets/new_data2022.csv')

# %%
new_df = pd.concat([df_19, df_20, df_21, df_22], ignore_index=True)
new_df
# Out:
#              director_name         actor_1_name        actor_2_name
# 0             Adam Robitel       Taylor Russell        Logan Miller  \
# 1              Jen McGowan    Hermione Corfield         Jay Paulson
# 2        Wilson Coneybeare    Donald Sutherland  Vincent Kartheiser
# 3     Charles Martin Smith  Bryce Dallas Howard  Edward James Olmos
# 4              Neil Burger       Bryan Cranston          Kevin Hart
# ...                    ...                  ...                 ...
# 1133          Kasi Lemmons          Naomi Ackie       Stanley Tucci
# 1134          Scott Cooper       Christian Bale       Harry Melling
# 1135          Sarah Polley          Rooney Mara          Claire Foy
# 1136          Marc Forster            Tom Hanks     Mariana Treviño
# 1137            Mary Nighy        Anna Kendrick     Kaniehtiio Horn
#
#           actor_3_name                       genres
# 0     Deborah Ann Woll      Horror Thriller Mystery  \
# ...

# %%
old_df = pd.read_csv('datasets/new_data.csv')
old_df
# Out:
#              director_name     actor_1_name      actor_2_name
# 0            James Cameron      CCH Pounder  Joel David Moore  \
# 1           Gore Verbinski      Johnny Depp     Orlando Bloom
# 2               Sam Mendes  Christoph Waltz      Rory Kinnear
# 3        Christopher Nolan        Tom Hardy    Christian Bale
# 4              Doug Walker      Doug Walker        Rob Walker
# ...                    ...              ...               ...
# 4917          Joe Carnahan       Will Smith   Martin Lawrence
# 4918       Timo Vuorensola         Udo Kier      Julia Dietze
# 4919     Haifaa Al-Mansour     Elle Fanning     Douglas Booth
# 4920          Orson Welles      John Huston     Robert Random
# 4921  Vladimir de Fontenay     Imogen Poots     Callum Turner
#
#               actor_3_name                           genres
# 0                Wes Studi  Action Adventure Fantasy Sci-Fi  \
# 1           Jack Davenport         Action Adventure Fantasy
# ...

# %%
final_df = pd.concat([old_df, new_df], ignore_index=True)
final_df
# Out:
#           director_name     actor_1_name      actor_2_name
# 0         James Cameron      CCH Pounder  Joel David Moore  \
# 1        Gore Verbinski      Johnny Depp     Orlando Bloom
# 2            Sam Mendes  Christoph Waltz      Rory Kinnear
# 3     Christopher Nolan        Tom Hardy    Christian Bale
# 4           Doug Walker      Doug Walker        Rob Walker
# ...                 ...              ...               ...
# 6055       Kasi Lemmons      Naomi Ackie     Stanley Tucci
# 6056       Scott Cooper   Christian Bale     Harry Melling
# 6057       Sarah Polley      Rooney Mara        Claire Foy
# 6058       Marc Forster        Tom Hanks   Mariana Treviño
# 6059         Mary Nighy    Anna Kendrick   Kaniehtiio Horn
#
#               actor_3_name                           genres
# 0                Wes Studi  Action Adventure Fantasy Sci-Fi  \
# 1           Jack Davenport         Action Adventure Fantasy
# 2         Stephanie Sigman        Action Adventure Thriller
# ...

# %%
final_df.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# movie_title      0
# comb             0
# dtype: int64

# %%
# convert to csv file
final_df.to_csv('datasets/main_data.csv', index=False)
