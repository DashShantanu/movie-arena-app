# %%
import numpy as np
import pandas as pd

# %%
credits = pd.read_csv('./datasets/credits.csv')

# %%
credits
# Out:
#                                                     cast
# 0      [{'cast_id': 14, 'character': 'Woody (voice)',...  \
# 1      [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2      [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# 3      [{'cast_id': 1, 'character': "Savannah 'Vannah...
# 4      [{'cast_id': 1, 'character': 'George Banks', '...
# ...                                                  ...
# 45471  [{'cast_id': 0, 'character': '', 'credit_id': ...
# 45472  [{'cast_id': 1002, 'character': 'Sister Angela...
# 45473  [{'cast_id': 6, 'character': 'Emily Shaw', 'cr...
# 45474  [{'cast_id': 2, 'character': '', 'credit_id': ...
# 45475                                                 []
#
#                                                     crew      id
# 0      [{'credit_id': '52fe4284c3a36847f8024f49', 'de...     862
# 1      [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...    8844
# 2      [{'credit_id': '52fe466a9251416c75077a89', 'de...   15602
# ...

# %%
meta = pd.read_csv('./datasets/movies_metadata.csv')
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_18588\1173797539.py:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   meta = pd.read_csv('./datasets/movies_metadata.csv')

# %%
meta['release_date'] = pd.to_datetime(meta['release_date'], errors='coerce')

meta['year'] = meta['release_date'].dt.year

# %%
meta['year'].value_counts().sort_index()
# Out:
# year
# 1874.0       1
# 1878.0       1
# 1883.0       1
# 1887.0       1
# 1888.0       2
#           ...
# 2015.0    1905
# 2016.0    1604
# 2017.0     532
# 2018.0       5
# 2020.0       1
# Name: count, Length: 135, dtype: int64

# %%
# Getting only 2018 movies as we already have movies up to the year 2016 in preprocessing 1 file. 
# We don't have enough data for the movies from 2019 and 2020.
new_meta = meta.loc[meta.year == 2018,['genres','id','original_title','year']]

# %%
new_meta
# Out:
#                                                                            genres
# 30402  [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'name': 'Action'}, {'id': 8...  \
# 33359  [{'id': 28, 'name': 'Action'}, {'id': 35, 'name': 'Comedy'}, {'id': 14,...
# 38130             [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'name': 'Romance'}]
# 38885                 [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'name': 'Drama'}]
# 44535                                               [{'id': 18, 'name': 'Drama'}]
#
#            id              original_title    year
# 30402   38700           Bad Boys for Life  2018.0
# 33359  302349   Iron Sky: The Coming Race  2018.0
# 38130  332283                Mary Shelley  2018.0
# 38885  299782  The Other Side of the Wind  2018.0
# 44535  412059                Mobile Homes  2018.0

# %%
new_meta['id'] = new_meta['id'].astype(int)

# %%
data = pd.merge(new_meta, credits, on='id')

# %%
pd.set_option('display.max_colwidth', 75)
data
# Out:
#                                                                        genres
# 0  [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'name': 'Action'}, {'id': 8...  \
# 1  [{'id': 28, 'name': 'Action'}, {'id': 35, 'name': 'Comedy'}, {'id': 14,...
# 2             [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'name': 'Romance'}]
# 3                 [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'name': 'Drama'}]
# 4                                               [{'id': 18, 'name': 'Drama'}]
#
#        id              original_title    year
# 0   38700           Bad Boys for Life  2018.0  \
# 1  302349   Iron Sky: The Coming Race  2018.0
# 2  332283                Mary Shelley  2018.0
# 3  299782  The Other Side of the Wind  2018.0
# 4  412059                Mobile Homes  2018.0
#
#                                                                          cast
# 0  [{'cast_id': 0, 'character': 'Detective Mike Lowrey', 'credit_id': '56b...  \
# ...

# %%
# evaluates an expression node or a string containing a Python literal or container display
import ast
data['genres'] = data['genres'].map(lambda x: ast.literal_eval(x))
data['cast'] = data['cast'].map(lambda x: ast.literal_eval(x))
data['crew'] = data['crew'].map(lambda x: ast.literal_eval(x))

# %%
def make_genresList(x):
    gen = []
    st = " "
    for i in x:
        if i.get('name') == 'Science Fiction':
            scifi = 'Sci-Fi'
            gen.append(scifi)
        else:
            gen.append(i.get('name'))
    if gen == []:
        return np.NaN
    else:
        return (st.join(gen))

# %%
data['genres_list'] = data['genres'].map(lambda x: make_genresList(x))

# %%
data['genres_list']
# Out:
# 0           Thriller Action Crime
# 1    Action Comedy Fantasy Sci-Fi
# 2                   Drama Romance
# 3                    Comedy Drama
# 4                           Drama
# Name: genres_list, dtype: object

# %%
def get_actor1(x):
    casts = []
    for i in x:
        casts.append(i.get('name'))
    if casts == []:
        return np.NaN
    else:
        return (casts[0])

# %%
data['actor_1_name'] = data['cast'].map(lambda x: get_actor1(x))

# %%
def get_actor2(x):
    casts = []
    for i in x:
        casts.append(i.get('name'))
    if casts == [] or len(casts)<=1:
        return np.NaN
    else:
        return (casts[1])

# %%
data['actor_2_name'] = data['cast'].map(lambda x: get_actor2(x))

# %%
data['actor_2_name']
# Out:
# 0    Martin Lawrence
# 1       Julia Dietze
# 2      Douglas Booth
# 3      Robert Random
# 4      Callum Turner
# Name: actor_2_name, dtype: object

# %%
def get_actor3(x):
    casts = []
    for i in x:
        casts.append(i.get('name'))
    if casts == [] or len(casts)<=2:
        return np.NaN
    else:
        return (casts[2])

# %%
data['actor_3_name'] = data['cast'].map(lambda x: get_actor3(x))

# %%
data['actor_3_name']
# Out:
# 0        Derrick Gilbert
# 1          Lloyd Kaufman
# 2             Bel Powley
# 3      Peter Bogdanovich
# 4    Callum Keith Rennie
# Name: actor_3_name, dtype: object

# %%
def get_directors(x):
    dt = []
    st = " "
    for i in x:
        if i.get('job') == 'Director':
            dt.append(i.get('name'))
    if dt == []:
        return np.NaN
    else:
        return (st.join(dt))

# %%
data['director_name'] = data['crew'].map(lambda x: get_directors(x))

# %%
data['director_name']
# Out:
# 0            Joe Carnahan
# 1         Timo Vuorensola
# 2       Haifaa Al-Mansour
# 3            Orson Welles
# 4    Vladimir de Fontenay
# Name: director_name, dtype: object

# %%
movie = data.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres_list','original_title']]

# %%
movie
# Out:
#           director_name  actor_1_name     actor_2_name         actor_3_name
# 0          Joe Carnahan    Will Smith  Martin Lawrence      Derrick Gilbert  \
# 1       Timo Vuorensola      Udo Kier     Julia Dietze        Lloyd Kaufman
# 2     Haifaa Al-Mansour  Elle Fanning    Douglas Booth           Bel Powley
# 3          Orson Welles   John Huston    Robert Random    Peter Bogdanovich
# 4  Vladimir de Fontenay  Imogen Poots    Callum Turner  Callum Keith Rennie
#
#                     genres_list              original_title
# 0         Thriller Action Crime           Bad Boys for Life
# 1  Action Comedy Fantasy Sci-Fi   Iron Sky: The Coming Race
# 2                 Drama Romance                Mary Shelley
# 3                  Comedy Drama  The Other Side of the Wind
# 4                         Drama                Mobile Homes

# %%
movie.isna().sum()
# Out:
# director_name     0
# actor_1_name      0
# actor_2_name      0
# actor_3_name      0
# genres_list       0
# original_title    0
# dtype: int64

# %%
movie = movie.dropna(how='any')

# %%
movie.isna().sum()
# Out:
# director_name     0
# actor_1_name      0
# actor_2_name      0
# actor_3_name      0
# genres_list       0
# original_title    0
# dtype: int64

# %%
movie = movie.rename(columns={'genres_list':'genres'})
movie = movie.rename(columns={'original_title':'movie_title'})

# %%
movie['movie_title'] = movie['movie_title'].str.lower()

# %%
movie['comb'] = movie['actor_1_name'] + ' ' + movie['actor_2_name'] + ' '+ movie['actor_3_name'] + ' '+ movie['director_name'] +' ' + movie['genres']

# %%
movie
# Out:
#           director_name  actor_1_name     actor_2_name         actor_3_name
# 0          Joe Carnahan    Will Smith  Martin Lawrence      Derrick Gilbert  \
# 1       Timo Vuorensola      Udo Kier     Julia Dietze        Lloyd Kaufman
# 2     Haifaa Al-Mansour  Elle Fanning    Douglas Booth           Bel Powley
# 3          Orson Welles   John Huston    Robert Random    Peter Bogdanovich
# 4  Vladimir de Fontenay  Imogen Poots    Callum Turner  Callum Keith Rennie
#
#                          genres                 movie_title
# 0         Thriller Action Crime           bad boys for life  \
# 1  Action Comedy Fantasy Sci-Fi   iron sky: the coming race
# 2                 Drama Romance                mary shelley
# 3                  Comedy Drama  the other side of the wind
# 4                         Drama                mobile homes
#
#                                                                          comb
# ...

# %%
old = pd.read_csv('./datasets/data.csv')

# %%
old
# Out:
#           director_name     actor_1_name      actor_2_name
# 0         James Cameron      CCH Pounder  Joel David Moore  \
# 1        Gore Verbinski      Johnny Depp     Orlando Bloom
# 2            Sam Mendes  Christoph Waltz      Rory Kinnear
# 3     Christopher Nolan        Tom Hardy    Christian Bale
# 4           Doug Walker      Doug Walker        Rob Walker
# ...                 ...              ...               ...
# 5038        Scott Smith      Eric Mabius     Daphne Zuniga
# 5039            unknown      Natalie Zea     Valorie Curry
# 5040   Benjamin Roberds      Eva Boehnke     Maxwell Moody
# 5041        Daniel Hsia        Alan Ruck     Daniel Henney
# 5042           Jon Gunn      John August  Brian Herzlinger
#
#               actor_3_name                           genres
# 0                Wes Studi  Action Adventure Fantasy Sci-Fi  \
# 1           Jack Davenport         Action Adventure Fantasy
# 2         Stephanie Sigman        Action Adventure Thriller
# ...

# %%
old['comb'] = old['actor_1_name'] + ' ' + old['actor_2_name'] + ' '+ old['actor_3_name'] + ' '+ old['director_name'] +' ' + old['genres']

# %%
old
# Out:
#           director_name     actor_1_name      actor_2_name
# 0         James Cameron      CCH Pounder  Joel David Moore  \
# 1        Gore Verbinski      Johnny Depp     Orlando Bloom
# 2            Sam Mendes  Christoph Waltz      Rory Kinnear
# 3     Christopher Nolan        Tom Hardy    Christian Bale
# 4           Doug Walker      Doug Walker        Rob Walker
# ...                 ...              ...               ...
# 5038        Scott Smith      Eric Mabius     Daphne Zuniga
# 5039            unknown      Natalie Zea     Valorie Curry
# 5040   Benjamin Roberds      Eva Boehnke     Maxwell Moody
# 5041        Daniel Hsia        Alan Ruck     Daniel Henney
# 5042           Jon Gunn      John August  Brian Herzlinger
#
#               actor_3_name                           genres
# 0                Wes Studi  Action Adventure Fantasy Sci-Fi  \
# 1           Jack Davenport         Action Adventure Fantasy
# 2         Stephanie Sigman        Action Adventure Thriller
# ...

# %%
new = pd.concat([old, movie], ignore_index=True)

# %%
new
# Out:
#              director_name     actor_1_name      actor_2_name
# 0            James Cameron      CCH Pounder  Joel David Moore  \
# 1           Gore Verbinski      Johnny Depp     Orlando Bloom
# 2               Sam Mendes  Christoph Waltz      Rory Kinnear
# 3        Christopher Nolan        Tom Hardy    Christian Bale
# 4              Doug Walker      Doug Walker        Rob Walker
# ...                    ...              ...               ...
# 5043          Joe Carnahan       Will Smith   Martin Lawrence
# 5044       Timo Vuorensola         Udo Kier      Julia Dietze
# 5045     Haifaa Al-Mansour     Elle Fanning     Douglas Booth
# 5046          Orson Welles      John Huston     Robert Random
# 5047  Vladimir de Fontenay     Imogen Poots     Callum Turner
#
#               actor_3_name                           genres
# 0                Wes Studi  Action Adventure Fantasy Sci-Fi  \
# 1           Jack Davenport         Action Adventure Fantasy
# ...

# %%
new.drop_duplicates(subset ="movie_title", keep = 'last', inplace = True)

# %%
new
# Out:
#              director_name     actor_1_name      actor_2_name
# 0            James Cameron      CCH Pounder  Joel David Moore  \
# 1           Gore Verbinski      Johnny Depp     Orlando Bloom
# 2               Sam Mendes  Christoph Waltz      Rory Kinnear
# 3        Christopher Nolan        Tom Hardy    Christian Bale
# 4              Doug Walker      Doug Walker        Rob Walker
# ...                    ...              ...               ...
# 5043          Joe Carnahan       Will Smith   Martin Lawrence
# 5044       Timo Vuorensola         Udo Kier      Julia Dietze
# 5045     Haifaa Al-Mansour     Elle Fanning     Douglas Booth
# 5046          Orson Welles      John Huston     Robert Random
# 5047  Vladimir de Fontenay     Imogen Poots     Callum Turner
#
#               actor_3_name                           genres
# 0                Wes Studi  Action Adventure Fantasy Sci-Fi  \
# 1           Jack Davenport         Action Adventure Fantasy
# ...

# %%
new.to_csv('new_data.csv',index=False)
